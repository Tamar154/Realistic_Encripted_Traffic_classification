# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
# Load the data
df = pd.read_csv('/content/drive/My Drive/FinalProject/output.csv')

# %%
df.head()
# Out:
#                                            Pcap File  \
# 0  Data\browsing\bbc.com\corrupt --rate 5%\2024-0...
# 1  Data\browsing\bbc.com\corrupt --rate 5%\2024-0...
# 2  Data\browsing\bbc.com\corrupt --rate 5%\2024-0...
# 3  Data\browsing\bbc.com\corrupt --rate 5%\2024-0...
# 4  Data\browsing\bbc.com\delay --time 200ms\2024-...
#
#              First Packet Sizes  Total Packets  Total Bytes  Bits per Peak  \
# 0  [1292, 1292, 1292, 1292, 54]           1866       537278          40928
# 1          [66, 66, 66, 66, 66]           3306       680312          46072
# 2          [58, 54, 56, 83, 58]           3095       730200          45088
# 3  [1292, 1292, 1292, 1292, 66]           2157      1064778         115632
# 4          [54, 54, 54, 54, 54]           1556       547284          41432
#
#    Mean Packet Size  Variance Packet Size  Skewness Packet Size  \
# 0        287.930332         307273.492195              3.575812
# 1        205.781004         191073.617382              4.704461
# 2        235.928918         238234.239936              4.162539
# 3        493.638387         605882.641902              5.398308
# 4        351.724936         366038.629114              2.971549
#
#    Mean Inter-arrival Time  Variance Inter-arrival Time  \
# 0                 0.019493                     0.005450
# 1                 0.010998                     0.006896
# 2                 0.011137                     0.002771
# 3                 0.015901                     0.011349
# 4                 0.025270                     0.011533
#
#    Skewness Inter-arrival Time  Bandwidth (bytes/sec)  Packets per Second  \
# 0                     7.219480           14779.132188           51.328848
# 1                    19.229919           18715.692057           90.949561
# 2                     8.916954           21192.026226           89.823776
# 3                    17.268042           31059.829182           62.920206
# 4                     7.663760           13927.406545           39.597439
#
#    Flow Duration (sec)  Source IPs  Destination IPs  \
# 0            36.353826          75               80
# 1            36.349818          79               84
# 2            34.456356          72               74
# 3            34.281515          44               44
# 4            39.295471          64               67
#
#                                            Protocols  \
# 0  SSL,MDNS,TLSv1.2,TCP,IGMPv2,DNS,TLSv1,TLSv1.3,...
# 1        SSDP,SSL,TLSv1.2,TCP,DNS,TLSv1,TLSv1.3,QUIC
# 2  SSDP,SSL,TLSv1.2,TCP,IGMPv2,DNS,TLSv1,TLSv1.3,...
# 3         SSL,TCP,TLSv1.2,DNS,TLSv1,UDP,TLSv1.3,QUIC
# 4        SSDP,SSL,TLSv1.2,TCP,DNS,TLSv1,TLSv1.3,QUIC
#
#                                           TTL Values     Label
# 0  48,54,36,240,231,233,39,226,98,228,40,215,47,4...  browsing
# 1  48,237,54,36,240,231,233,39,226,228,215,47,46,...  browsing
# 2  48,54,240,231,233,39,35,228,223,43,33,38,235,1...  browsing
# 3  36,240,233,39,226,228,46,43,33,236,38,128,56,2...  browsing
# 4  237,54,36,240,231,233,39,35,47,43,33,225,38,12...  browsing

# %%
# Drop non-numeric and irrelevant columns
df = df.drop(columns=["Pcap File", "Protocols", "TTL Values", "First Packet Sizes"])

# Drop rows with null values
df = df.dropna()

label_encoder = LabelEncoder()
df['Label'] = label_encoder.fit_transform(df['Label'])  # Encode labels

X = df.drop(columns=["Label"])  # Features
y = df["Label"]  # Target

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Fit the model
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predict on the test set
y_pred = rf_classifier.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9787

# %%
# Detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#           VOD       0.95      0.98      0.96       150
#      browsing       1.00      0.97      0.98       223
# file download       0.97      0.99      0.98       120
#   file-upload       0.99      0.98      0.99       164
#
#      accuracy                           0.98       657
#     macro avg       0.98      0.98      0.98       657
#  weighted avg       0.98      0.98      0.98       657

# %%
# Confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[147   1   1   1]
#  [  6 216   1   0]
#  [  1   0 119   0]
#  [  1   0   2 161]]
